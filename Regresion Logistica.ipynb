# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar el datasets
df1 = pd.read_csv('E:/UNAD/UNAD 2025/PRIMER SEMESTRE/ANALISIS DE DATOS/Tarea 3/Heart Disease Cleveland UCI/heart_cleveland_upload.csv')

# %%
# Mostrar las primeras filas del dataset para entender su estructura
df1.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    69    1   0       160   234    1        2      131      0      0.1
# 1    69    0   0       140   239    0        0      151      0      1.8
# 2    66    0   0       150   226    0        0      114      0      2.6
# 3    65    1   0       138   282    1        2      174      0      1.4
# 4    64    1   0       110   211    0        2      144      1      1.8
# 5    64    1   0       170   227    0        2      155      0      0.6
# 6    63    1   0       145   233    1        2      150      0      2.3
# 7    61    1   0       134   234    0        0      145      0      2.6
# 8    60    0   0       150   240    0        0      171      0      0.9
# 9    59    1   0       178   270    0        2      145      0      4.2
# 10   59    1   0       170   288    0        2      159      0      0.2
# 11   59    1   0       160   273    0        2      125      0      0.0
# ...

# %%
# Ver información general y valores nulos
df1.info()
df1.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        297 non-null    int64
#  1   sex        297 non-null    int64
#  2   cp         297 non-null    int64
#  3   trestbps   297 non-null    int64
#  4   chol       297 non-null    int64
#  5   fbs        297 non-null    int64
#  6   restecg    297 non-null    int64
#  7   thalach    297 non-null    int64
#  8   exang      297 non-null    int64
#  9   oldpeak    297 non-null    float64
#  10  slope      297 non-null    int64
#  11  ca         297 non-null    int64
#  12  thal       297 non-null    int64
#  13  condition  297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ...

# %%
# Descripción estadística

df1.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# ...

# %%
# Visualizar correlaciones

plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.title("Matriz de correlación")
plt.show()

# %%
# Relación entre variables y la condición cardíaca

sns.boxplot(x='condition', y='age', data=df1)
plt.title("Edad vs Condición Cardíaca")
plt.show()

sns.boxplot(x='condition', y='chol', data=df1)
plt.title("Colesterol vs Condición Cardíaca")
plt.show()

sns.countplot(x='cp', hue='condition', data=df1)
plt.title("Tipo de Dolor en el Pecho por Condición")
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, chi2

selector = SelectKBest(score_func=chi2, k=10)
X_new = selector.fit_transform(X, y)

# Mostrar las columnas seleccionadas

selected_features = X.columns[selector.get_support()]
print("Características seleccionadas:", selected_features)
# Out:
# Características seleccionadas: Index(['age', 'cp', 'trestbps', 'chol', 'thalach', 'exang', 'oldpeak', 'slope',
#        'ca', 'thal'],
#       dtype='object')

# %%
# Dividimos el dataset en Train/Test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# %%
# Entrenar el modelo 

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Evaluacion del modelo

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

y_pred = model.predict(X_test)

print("Reporte de Clasificación:\n", classification_report(y_test, y_pred))
#print("Matriz de Confusión:\n", confusion_matrix(y_test, y_pred))
# Out:
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        32
#            1       0.81      0.79      0.80        28
#
#     accuracy                           0.82        60
#    macro avg       0.82      0.81      0.82        60
# weighted avg       0.82      0.82      0.82        60
#
# Matriz de Confusión:
#  [[27  5]
#  [ 6 22]]

# %%
# VISUALIZAMOS LOS RESULTADO

# Matriz de confusion

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title("Matriz de Confusión")
plt.show()

# %%
# Curva ROC

y_prob = model.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_prob):.2f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC")
plt.legend()
plt.show()
